# %% [markdown]
# # Exploring the Dataset

# %%
import pandas as pd

from plots import boxplot_salary_gender_job_title, \
                histogram_salary_company_size, \
                histogram_weekly_hours_seniority_level
from utils import get_frequent_company_locations

# %%
df = pd.read_csv("data/df_salaries.csv")

# %%
df.company_location.unique()
# Out:
# array(['ESP', 'USA', 'CAN', 'DEU', 'GBR', 'NGA', 'IND', 'HKG', 'NLD',
#        'CHE', 'CAF', 'FRA', 'FIN', 'UKR', 'IRL', 'ISR', 'GHA', 'COL',
#        'SGP', 'AUS', 'SWE', 'SVN', 'MEX', 'BRA', 'PRT', 'RUS', 'THA',
#        'HRV', 'VNM', 'EST', 'ARM', 'BIH', 'KEN', 'GRC', 'MKD', 'LVA',
#        'ROU', 'PAK', 'ITA', 'MAR', 'POL', 'ALB', 'ARG', 'LTU', 'ASM',
#        'CRI', 'IRN', 'BHS', 'HUN', 'AUT', 'SVK', 'CZE', 'TUR', 'PRI',
#        'DNK', 'BOL', 'PHL', 'BEL', 'IDN', 'EGY', 'ARE', 'LUX', 'MYS',
#        'HND', 'JPN', 'DZA', 'IRQ', 'CHN', 'NZL', 'CHL', 'MDA', 'MLT'],
#       dtype=object)

# %%
df.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence remote_ratio  \
# 0   80000             EUR          85847                 ES       remote
# 1   30000             USD          30000                 US       remote
# 2   25500             USD          25500                 US       remote
# 3  175000             USD         175000                 CA       remote
# 4  120000             USD         120000                 CA       remote
#
#   company_location company_size  weekly_hours  age  gender job_title_grouped
# ...

# %% [markdown]
# ## Which Job should I pursue?

# %% [markdown]
# ### 1- Salary by gender and job title

# %%
fig = boxplot_salary_gender_job_title(df)
fig

# %% [markdown]
# ### 2- Histogram of salaries by company size

# %%
fig = histogram_salary_company_size(df)
fig

# %% [markdown]
# ### 3- Histogram comparing working hours between countries by seniority level

# %% [markdown]
# Analyzing work-life balance and weekly hours between different seniority levels and accross multiple countries.

# %%
company_locations = get_frequent_company_locations(df)
filtered_df = df[df['company_location'].isin(company_locations)]
fig = histogram_weekly_hours_seniority_level(filtered_df)
fig
